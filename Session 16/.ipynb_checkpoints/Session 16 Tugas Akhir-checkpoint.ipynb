# %% [markdown]
# # Titanic Kaggle Set

# %% [markdown]
# # Project Description

# %% [markdown]
# Dalam proyek ini saya menerapkan alat pembelajaran mesin untuk memprediksi penumpang mana yang selamat dari tragedi Titanic. saya memberikan contoh dua set data, dataset pelatihan dan dataset uji. Model pembelajaran mesin akan dibuat dari set data pelatihan. Dan dataset uji akan digunakan untuk menguji kinerja model sebelumnya.
#
# * Setelah membangun **aplikasi web** menggunakan model, saya akan menerapkannya ke **Heroku**.
#
# * Full data dari project dan dataset dari(https://www.kaggle.com/c/titanic/overview)**.
#
# * Data

# %% [markdown]
# | Variable | Definition   | Key   |
# |----------|--------------|-------|
# |  survival| Survival     |0 = No, 1 = Yes|
# |pclass    | Ticket class |1 = 1st, 2 = 2nd, 3 = 3rd|
# |sex       | Sex|
# |Age  |Age in years|
# |sibsp|# of siblings / spouses aboard the Titanic|
# |parch|# of parents / children aboard the Titanic|
# |ticket|Ticket number|
# |fare|Passenger fare|
# |cabin|Cabin number|
# |embarked|Port of Embarkation|C = Cherbourg, Q = Queenstown, S = Southampton|

# %% [markdown]
# # Import Libraries

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
import pickle


from collections import Counter
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer


from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, learning_curve
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score

# custom estimator
from custom_estimators import FeatureSelector, IsAlone, ExtractName

# %%
sns.set(style = 'ticks')
# %matplotlib inline
matplotlib.rcParams['figure.dpi'] = 144

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Pertama, kita tampilkan isi dari dataset.

# %%
train_data = pd.read_csv('data/train.csv')
test_data = pd.read_csv('data/test.csv')

# %% [markdown]
# ## Observations and Assumptions

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Variabel target adalah **Survived**  dan sisanya adalah variabel prediktor. Mari kita lihat informasi dasar kumpulan data.

# %%
train_data.shape, test_data.shape
# Out:
# ((891, 12), (418, 11))

# %%
train_data.info(), print(), test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %% [markdown]
# Check missing values.

# %%
train_data.isna().any(), print(), test_data.isna().any()
# Out:
# (PassengerId    False
#  Survived       False
#  Pclass         False
#  Name           False
#  Sex            False
#  Age             True
#  SibSp          False
#  Parch          False
#  Ticket         False
#  Fare           False
#  Cabin           True
#  Embarked        True
#  dtype: bool,
#  None,
#  PassengerId    False
#  Pclass         False
#  Name           False
#  Sex            False
#  Age             True
#  SibSp          False
#  Parch          False
#  Ticket         False
#  Fare            True
#  Cabin           True
#  Embarked       False
#  dtype: bool)

# %% [markdown]
# **Variables with missing values:**
# train_data: *Age, Cabin and Embarked*
# test_data: *Age, Fare and Cabin*
# Mari kita terus mencari tahu lebih banyak tentang nilai-nilai yang hilang.

# %%
def count_na(df, columns):
    '''
    Count the missing values by column.
    
    Parameters:
        df: dataframe
        columns: columns of the dataframe
    Returns: Number of missing values by column
    '''
    
    counts = [(df[col].isna() == 1).sum() for col in columns]
    print([(columns[i], counts[i]) for i in range(len(columns))])

# %%
# Number of missing values in train_data
count_na(train_data, ['Age', 'Cabin', 'Embarked'])

#Number of missing values in test_data
count_na(test_data, ['Age', 'Cabin', 'Fare'])
# Out:
# [('Age', 177), ('Cabin', 687), ('Embarked', 2)]
# [('Age', 86), ('Cabin', 327), ('Fare', 1)]

# %% [markdown]
# Kita juga ingin melihat distribusi variabel.

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_data.describe(include = ['O'])
# Out:
#                                                 Name   Sex Ticket Cabin  \
# count                                            891   891    891   204
# unique                                           891     2    681   147
# top     Andersson, Mr. August Edvard ("Wennerstrom")  male   1601    G6
# freq                                               1   577      7     4
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644

# %% [markdown]
# **Inilah yang ditemukan sejauh ini.**
# **Info**
# >
# > 1. Dimension
#        train_data: 891*12
#        test_data : 418*11
# > 2. Data types
#        Categorical: Survived, Sex, Embarked
#        Ordinal: Pclass
#        Numerical:
#            Continuous: Age, Fare
#            Discrete: PassengerId, SibSp, Parch
#        Mixed: Ticket, Cabin
# > 3. Number of missing values
#        train: Cabin > Age > Embarked
#        test: Cabin > Age > Fare
#
# **Observasi**
# >
# >    1. Age-[<1, 80], Fare-[0, 512]
# >    2. Male = 577/891 = 65%, female = 35%
# >    3. Three Embarkation ports
# >    4. Duplication rate of Ticket = 23.6%
#         Duplication rate of Cabin = 27.9%
# >    5. 50% - 75% of passengers travel alone (SibSp, Parch)
#
# **Asumsi**
# >
# >    1. Kabin mungkin putus (Mayoritas nilai terlewatkan)
# >    2. Tiket dapat dibatalkan (Tingkat duplikasi tinggi)
# >    3. PassengerId and Name mungkin akan dikeluarkan.
# >    4. Combine SibSp and Parch jika memungkinkan.
# >    5. Age, Embarked, Fare lakukan fillna()
# >    6. Dari description, Sex, Age and Pclass mungkin berhubungan langsung dengan tingkat kelangsungan hidup

# %% [markdown]
# ## Features Analysis

# %% [markdown]
# ### Pclass vs. Survived

# %%
train_data[['Pclass', 'Survived']].groupby('Pclass').mean().sort_values(by = 'Survived', ascending = False)
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %% [markdown]
# Penumpang di kelas 1 memiliki tingkat kelangsungan hidup yang lebih tinggi rata-rata 62,96%. Mengingat tiket di kelas 1 paling mahal, itu mungkin menunjukkan bahwa mereka yang membayar lebih untuk tiket lebih mungkin bertahan. Mari kita lihat fare vs. survived.

# %% [markdown]
# ### Fare vs. Survived

# %%
g = sns.FacetGrid(train_data, col = 'Survived')
g = g.map(sns.distplot, 'Fare', bins = 50, kde = False)
g.set_axis_labels('Fare','Value $')
g.fig.subplots_adjust(top = 0.8)
g.fig.suptitle("Fare vs. Survived")
plt.show()
# Out:
# C:\Users\BRI\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Distribusi tarif miring. Kita mungkin ingin melakukan **log transfrom** nanti.
#
# Jelas bahwa mayoritas korban adalah mereka yang membayar kurang dari \\$50 untuk tiket. Di sisi lain, sebagian besar penumpang yang membayar lebih dari $100 selamat. Ini memperkuat asumsi kami sebelumnya. Jadi kita mungkin ingin menyimpan "Pclass" dan "Fare" dalam model.
#
# Kita bisa melihat bahwa sejumlah kecil penumpang yang membayar lebih sedikit memang bertahan. Untuk saat ini, saya kira ini mungkin disumbangkan oleh jenis kelamin atau usia.

# %% [markdown]
# ### Sex vs. Survived

# %%
train_data[['Sex', 'Survived']].groupby('Sex').mean().sort_values('Survived', ascending = False)
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %% [markdown]
# Tidak mengherankan bahwa Wanita memiliki tingkat kelangsungan hidup yang jauh lebih tinggi daripada Pria. Kita mungkin ingin menjaga "SEX" dalam model.

# %% [markdown]
# ### Age vs. Survived

# %%
ticks = [i for i in np.arange(0, 90, 10)]
g = sns.FacetGrid(train_data, col = 'Survived')
g = g.map(sns.distplot, 'Age', bins = 50)
g.set(xticks = ticks)
g.set_axis_labels('Age','Probability')
g.fig.subplots_adjust(top = 0.8)
g.fig.suptitle("Age vs. Survived")
plt.show()
# Out:
# C:\Users\BRI\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\BRI\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Penumpang berusia <10 sebagian besar selamat, 20-40 sebagian besar tidak selamat, berusia 80 tahun selamat. Kami mungkin ingin mempertahankan "Age" dalam model.

# %% [markdown]
# ### SibSp vs. Survived

# %%
sns.barplot(x = train_data['SibSp'], y = train_data['Survived'])
plt.show()

# %% [markdown]
# ### Parch vs. Survived

# %%
sns.barplot(x = train_data['Parch'], y = train_data['Survived'])
plt.show()

# %% [markdown]
# Berdasarkan dua grafik di atas, penumpang dengan SibSp = 1 atau 2 dan Parch <=3 lebih berpeluang untuk bertahan. Namun, hubungan itu tampaknya tidak terlalu kuat. Terlihat bahwa penumpang yang bepergian sendiri (SibSp = 0 dan Parch = 0) memiliki peluang yang jauh lebih kecil untuk bertahan hidup. Mengingat 50% - 75% penumpang bepergian sendiri dari bagian 3.1, kami mungkin ingin menyimpan 'SibSp' dan 'Parch' karena kami perlu menunjukkan pelancong tunggal.

# %% [markdown]
# ### Embarked vs. Survived

# %%
train_data[['Embarked', 'Survived']].groupby('Embarked').mean().sort_values(by = 'Survived', ascending = False)
# Out:
#           Survived
# Embarked
# C         0.553571
# Q         0.389610
# S         0.336957

# %% [markdown]
# Penumpang yang memulai Cherbourg memiliki tingkat kelangsungan hidup yang lebih tinggi.Mungkin perlu mengkodekan variabel ini nanti.

# %% [markdown]
# ### Sex, Pclass, Embarked vs. Survived

# %%
g = sns.FacetGrid(train_data, col = 'Embarked')
g.map(sns.pointplot,'Pclass' ,'Survived', 'Sex', palette = 'bright')
g.fig.subplots_adjust(top = 0.8)
g.fig.suptitle("Sex, Pclass, Embarked vs. Survived")
g.add_legend()
plt.show()
# Out:
# C:\Users\BRI\anaconda3\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# C:\Users\BRI\anaconda3\lib\site-packages\seaborn\axisgrid.py:648: UserWarning: Using the pointplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# Hampir seperti yang kami temukan , laki-laki memiliki tingkat kelangsungan hidup rata-rata yang lebih rendah di Embark S dan Q. Namun, itu tidak terjadi di Embark C, menimbulkan pertanyaan apakah variabel 'memulai' akan berperan dalam model. Juga, mengingat ada 644 penumpang yang memulai S, kami mungkin ingin tetap 'Embarked' dalam model.

# %% [markdown]
# ### Age, Pclass vs. Survived

# %%
g = sns.FacetGrid(train_data, row = 'Pclass', col = 'Survived')
g.map(plt.hist, 'Age')
g.fig.subplots_adjust(top = 0.9)
g.fig.suptitle("Age, Pclass vs. Survived")
plt.show()

# %% [markdown]
# Sejumlah besar penumpang berusia antara 20 - 40 tidak bertahan di semua kelas, sementara sebagian besar anak-anak dan manula selamat. Juga, kelas 3 memiliki korban tertinggi. Ini konsisten dengan apa yang kami temukan di bagian "Pclass vs. Survived" and "Age vs. Survived".

# %% [markdown]
# ### Heatmap

# %%
sns.heatmap(train_data[['Survived', 'Age', 'SibSp', 'Parch', 'Fare']].corr(), annot=True, cmap='RdYlGn')
plt.show()

# %% [markdown]
# Di sini korelasi tertinggi keluar antara SibSp dan Parch. Alih-alih menyimpan keduanya dalam model, ini akan menipiskannya untuk mengurangi noise. Mengatakan mungkin ingin membuat variabel baru 'IsAlone' untuk menunjukkan jika penumpang bepergian sendiri.

# %% [markdown]
# ### Name

# %% [markdown]
# Saya mencoba mengekstrak judul untuk setiap penumpang.

# %%
title = [i.split(",")[1].split(".")[0].strip() for i in train_data["Name"]]
title = Counter(title)
title
# Out:
# Counter({'Mr': 517,
#          'Mrs': 125,
#          'Miss': 182,
#          'Master': 40,
#          'Don': 1,
#          'Rev': 6,
#          'Dr': 7,
#          'Mme': 1,
#          'Ms': 1,
#          'Major': 2,
#          'Lady': 1,
#          'Sir': 1,
#          'Mlle': 2,
#          'Col': 2,
#          'Capt': 1,
#          'the Countess': 1,
#          'Jonkheer': 1})

# %% [markdown]
# Judul berdasarkan Kategori:
# * Mr/Master: 0
# * Mrs/Miss: 1
# * Others: 2

# %% [markdown]
# **Inilah yang akan kita lakukan untuk rekayasa fitur.**
#
# 1.Keluarkan PassengerId, Name, Ticket and Cabin.
# 2. Buat fitur baru 'IsAlone'( = SibSp + Parch + 1) untuk menunjukkan jika penumpang sendirian.
# 3. Ekstrak judul dari Name.
# 4. Missing value imputasi dan normalisasi untuk fitur numerik.
# 5. Encode fitur kategoris.

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# **Semua transformator fitur dienkapsulasi dalam custom_estimators.py.**

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Creating the pipeline

# %%
# 'Embarked' has only two missing values
train_data['Embarked'].fillna(value = train_data['Embarked'].value_counts().index[0], inplace=True)
X = train_data.drop('Survived', axis = 1)
y = train_data['Survived']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
num_columns = ['Age', 'Fare']
cat_columns = ['Pclass', 'Sex', 'Embarked', 'IsAlone', 'Title'] # We will create the features 'IsAlone' and 'Title'

# %%
num_pipe = Pipeline([('num_selector', FeatureSelector(num_columns)),
                     ('imputer', SimpleImputer(strategy = 'median')),
                     ('Normalization', StandardScaler())])

# %%
cat_pipe = Pipeline([('cat_selector', FeatureSelector(cat_columns)),
                     ('ohe', OneHotEncoder(sparse = False))])

# %%
union = FeatureUnion([('num', num_pipe),
                      ('cat', cat_pipe)])

# %% [markdown]
# ## Plotting the learning curve

# %% [markdown]
# Di sini kita memilih beberapa pengklasifikasi untuk melihat kurva pembelajaran.

# %%
learning_curve_pipe = Pipeline([('IsAlone', IsAlone("SibSp", "Parch", 'IsAlone')),
                                ('Title', ExtractName('Title')),
                                ('union', union)])

# %%
X_curve = learning_curve_pipe.fit_transform(X)

# %%
def plot_learning_curve(clf, title, X, y):
    '''
    Plot the test and training learning curve.
    
    Parameters:
        clf: estimator
        title: graph title
    Returns:
        Learning curve
    '''
    
    train_sizes,train_scores,test_scores = learning_curve(clf,X,y,random_state = 42,cv = 5, shuffle = True)

    plt.figure()
    plt.title(title)
    
    ylim = (0.7, 1.01)
    if ylim is not None:
        plt.ylim(*ylim)
        
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                train_scores_mean + train_scores_std, alpha=0.1,
                color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
        label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
        label="Cross-validation score")

    plt.legend(loc="best")
    plt.show()

# %%
plot_learning_curve(LogisticRegression(solver = 'lbfgs'),'Learning Curve of Logistic Regression', X_curve, y)
plot_learning_curve(RandomForestClassifier(n_estimators = 100),'Learning Curve of Random Forest', X_curve, y)
plot_learning_curve(DecisionTreeClassifier(),'Learning Curve of Decision Tree', X_curve, y)
plot_learning_curve(xgb.XGBClassifier(),'Learning Curve of XGBoost', X_curve, y)
plot_learning_curve(SVC(gamma = 'scale'),'Learning Curve of SVM', X_curve, y)
# Out:
# C:\Users\BRI\anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [22:57:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %% [markdown]
# * Logistic Regression and SVM: Skor pelatihan menurun dan mendatar, dan skor CV stagnan - mungkin kurang pas.
# * Random Forest and Decision Tree: Skor pelatihan sekitar maksimum di sepanjang jalan, tetapi kesenjangannya sangat besar - mungkin terlalu pas.
# * XGBoost: Kesenjangannya relatif kecil - Model terbaik sejauh ini.

# %% [markdown]
# ## Tuning the Hyperparameters

# %% [markdown]
# Di sini kita menyetel hyperparameters untuk XGBoost.

# %%
clf = xgb.XGBClassifier()

pipe = Pipeline([('IsAlone', IsAlone("SibSp", "Parch", 'IsAlone')),
                 ('Title', ExtractName('Title')),
                 ('union', union),
                 ('classifier', clf)])

# %%
param_grid = {'classifier__learning_rate': [0.05, 0.10, 0.15, 0.20, 0.25, 0.30], 
              'classifier__max_depth': [3, 4, 5, 6, 8, 10, 12, 15], 
              'classifier__min_child_weight': [1, 3, 5, 7], 
              'classifier__gamma': [0.0, 0.1, 0.2, 0.3, 0.4], 
              'classifier__colsample_bytree': [0.3, 0.4, 0.5, 0.7],
              'union__num__imputer__strategy': ['median', 'mean']}

grid_search = GridSearchCV(pipe, param_grid, cv = 5, scoring = 'accuracy', n_jobs = -1, verbose = 1)
grid_search.fit(X_train, y_train)
best_model = grid_search.best_estimator_

# training score and CV score
result = "{} is {}"
print(result.format("Training score", grid_search.score(X_train, y_train)))
print(result.format("CV score", grid_search.best_score_))
print(result.format("Best parameter", grid_search.best_params_))

# Accuracy, AUC and F1
y_prediction = best_model.predict(X_test)
pred_proba = best_model.predict_proba(X_test)[:, 1]

print("=" * 100)
print(result.format("Accuracy", accuracy_score(y_test, y_prediction)))
print(result.format("AUC", roc_auc_score(y_test, pred_proba)))
print(result.format("F1 score", f1_score(y_test, y_prediction)))

# Feature importance
feature_importance = best_model.steps[3][1].feature_importances_
num_cols = best_model.named_steps['union'].transformer_list[0][1].steps[0][1].columns.copy()
cat_cols = best_model.named_steps['union'].transformer_list[1][1].steps[1][1].get_feature_names().copy()
num_cols.extend(cat_cols)
df = pd.DataFrame({'Feature': num_cols, 'Feature Importance': feature_importance}).sort_values("Feature Importance", ascending = False)
df
# Out:
# Fitting 5 folds for each of 7680 candidates, totalling 38400 fits

# %% [markdown]
# Model XGBoost memakan waktu, tetapi hasilnya mengesankan dengan akurasi 0,85 dan AUC 0,9. Dengan melihat tabel urgensi fitur, kita dapat mengamati bahwa "Sex", "Title"(x4) dan 'Pclass"(x0) adalah penentu utama kelangsungan hidup. Saya pikir ini konsisten dengan apa yang ditemukan di bagian "Eksplorasi Analisis data".

# %% [markdown]
# # Submission

# %%
# Prep the submission
y_pred = pd.Series(best_model.predict(test_data), name = 'Survived')
predict = pd.DataFrame({'PassengerId': test_data['PassengerId'],
                       "Survived": y_pred})

# %%
predict

# %% [markdown]
# # Model Deployment

# %% [markdown]
# Ini adalah langkah yang akan dilakukan:
#
# * Membangun web app menggunakan final model and Flask
# * Deploy dataset ke Heroku (Cloud platform)
# * Pengguna mengunjungi aplikasi web dan mendapatkan kemungkinan bertahan hidup dengan mengetikkan parameter seperti yang diinstruksikan

# %% [markdown]
# # Pickle

# %%
pickle.dump(random_forest, open('model_classifier.pkl','wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c9f6c65beb33> in <module>
# ----> 1 pickle.dump(random_forest, open('model_classifier.pkl','wb'))
#
# NameError: name 'random_forest' is not defined

# %% [markdown]
# # Kesimpulan

# %% [markdown]
# Pada data titanic ini menggunakan Classification Logistic Regression, SVM, Decision Tree,Random Forest, dan XGBoost yang menunjukkan bahwa, hasil data titanic from kagel lebih bagus pada saat menggunakan classification XGBoost

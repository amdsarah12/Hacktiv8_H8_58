# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Project-Description" data-toc-modified-id="Project-Description-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Project Description</a></span></li><li><span><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Import Libraries</a></span></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Observations-and-Assumptions" data-toc-modified-id="Observations-and-Assumptions-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Observations and Assumptions</a></span></li><li><span><a href="#Features-Analysis" data-toc-modified-id="Features-Analysis-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Features Analysis</a></span><ul class="toc-item"><li><span><a href="#Pclass-vs.-Survived" data-toc-modified-id="Pclass-vs.-Survived-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Pclass vs. Survived</a></span></li><li><span><a href="#Fare-vs.-Survived" data-toc-modified-id="Fare-vs.-Survived-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Fare vs. Survived</a></span></li><li><span><a href="#Sex-vs.-Survived" data-toc-modified-id="Sex-vs.-Survived-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Sex vs. Survived</a></span></li><li><span><a href="#Age-vs.-Survived" data-toc-modified-id="Age-vs.-Survived-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Age vs. Survived</a></span></li><li><span><a href="#SibSp-vs.-Survived" data-toc-modified-id="SibSp-vs.-Survived-3.2.5"><span class="toc-item-num">3.2.5&nbsp;&nbsp;</span>SibSp vs. Survived</a></span></li><li><span><a href="#Parch-vs.-Survived" data-toc-modified-id="Parch-vs.-Survived-3.2.6"><span class="toc-item-num">3.2.6&nbsp;&nbsp;</span>Parch vs. Survived</a></span></li><li><span><a href="#Embarked-vs.-Survived" data-toc-modified-id="Embarked-vs.-Survived-3.2.7"><span class="toc-item-num">3.2.7&nbsp;&nbsp;</span>Embarked vs. Survived</a></span></li><li><span><a href="#Sex,-Pclass,-Embarked-vs.-Survived" data-toc-modified-id="Sex,-Pclass,-Embarked-vs.-Survived-3.2.8"><span class="toc-item-num">3.2.8&nbsp;&nbsp;</span>Sex, Pclass, Embarked vs. Survived</a></span></li><li><span><a href="#Age,-Pclass-vs.-Survived" data-toc-modified-id="Age,-Pclass-vs.-Survived-3.2.9"><span class="toc-item-num">3.2.9&nbsp;&nbsp;</span>Age, Pclass vs. Survived</a></span></li><li><span><a href="#Heatmap" data-toc-modified-id="Heatmap-3.2.10"><span class="toc-item-num">3.2.10&nbsp;&nbsp;</span>Heatmap</a></span></li><li><span><a href="#Name" data-toc-modified-id="Name-3.2.11"><span class="toc-item-num">3.2.11&nbsp;&nbsp;</span>Name</a></span></li></ul></li></ul></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Feature Engineering</a></span></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Modeling</a></span><ul class="toc-item"><li><span><a href="#Creating-the-pipeline" data-toc-modified-id="Creating-the-pipeline-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Creating the pipeline</a></span></li><li><span><a href="#Plotting-the-learning-curve" data-toc-modified-id="Plotting-the-learning-curve-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Plotting the learning curve</a></span></li><li><span><a href="#Tuning-the-Hyperparameters" data-toc-modified-id="Tuning-the-Hyperparameters-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Tuning the Hyperparameters</a></span></li></ul></li><li><span><a href="#Submission" data-toc-modified-id="Submission-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Submission</a></span></li><li><span><a href="#Model-Deployment" data-toc-modified-id="Model-Deployment-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Model Deployment</a></span></li></ul></div>

# %% [markdown]
# # Project Description

# %% [markdown]
# * In this project we apply the the tools of machine learning to predict which passengers survived the Titanic tragedy. We are given two datasets, training dataset and test dataset. A machine learning model would be built out of the training dataset. And test dataset would be used to test the performance of previous model.
#
# * Once we buil up the **web app** using the model, we will deploy it to **Heroku**.
#
# * Full description of the project and datasets could be seen **[here](https://www.kaggle.com/c/titanic/overview)**.
#
# * Data Dictionary

# %% [markdown]
# | Variable | Definition   | Key   |
# |----------|--------------|-------|
# |  survival| Survival     |0 = No, 1 = Yes|
# |pclass    | Ticket class |1 = 1st, 2 = 2nd, 3 = 3rd|
# |sex       | Sex|
# |Age  |Age in years|
# |sibsp|# of siblings / spouses aboard the Titanic|
# |parch|# of parents / children aboard the Titanic|
# |ticket|Ticket number|
# |fare|Passenger fare|
# |cabin|Cabin number|
# |embarked|Port of Embarkation|C = Cherbourg, Q = Queenstown, S = Southampton|

# %% [markdown]
# # Import Libraries

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
import pickle


from collections import Counter
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer


from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, learning_curve
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score

# custom estimator
from custom_estimators import FeatureSelector, IsAlone, ExtractName

# %%
sns.set(style = 'ticks')
# %matplotlib inline
matplotlib.rcParams['figure.dpi'] = 144

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# First we load the datasets.

# %%
train_data = pd.read_csv('data/train.csv')
test_data = pd.read_csv('data/test.csv')

# %% [markdown]
# ## Observations and Assumptions

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# The target variable is **Survived** and the remaining are predictor variables. Let us take a look at the basic information of datasets.

# %%
train_data.shape, test_data.shape
# Out:
# ((891, 12), (418, 11))

# %%
train_data.info(), print(), test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %% [markdown]
# Check missing values.

# %%
train_data.isna().any(), print(), test_data.isna().any()
# Out:
# (PassengerId    False
#  Survived       False
#  Pclass         False
#  Name           False
#  Sex            False
#  Age             True
#  SibSp          False
#  Parch          False
#  Ticket         False
#  Fare           False
#  Cabin           True
#  Embarked        True
#  dtype: bool,
#  None,
#  PassengerId    False
#  Pclass         False
#  Name           False
#  Sex            False
#  Age             True
#  SibSp          False
#  Parch          False
#  Ticket         False
#  Fare            True
#  Cabin           True
#  Embarked       False
#  dtype: bool)

# %% [markdown]
# **Variables with missing values:**
# train_data: *Age, Cabin and Embarked*
# test_data: *Age, Fare and Cabin*
# Let us continue to find out more about missing values.

# %%
def count_na(df, columns):
    '''
    Count the missing values by column.
    
    Parameters:
        df: dataframe
        columns: columns of the dataframe
    Returns: Number of missing values by column
    '''
    
    counts = [(df[col].isna() == 1).sum() for col in columns]
    print([(columns[i], counts[i]) for i in range(len(columns))])

# %%
# Number of missing values in train_data
count_na(train_data, ['Age', 'Cabin', 'Embarked'])

#Number of missing values in test_data
count_na(test_data, ['Age', 'Cabin', 'Fare'])
# Out:
# [('Age', 177), ('Cabin', 687), ('Embarked', 2)]
# [('Age', 86), ('Cabin', 327), ('Fare', 1)]

# %% [markdown]
# Also we would like to see the distribution of variables.

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_data.describe(include = ['O'])
# Out:
#                     Name   Sex  Ticket    Cabin Embarked
# count                891   891     891      204      889
# unique               891     2     681      147        3
# top     Osman, Mrs. Mara  male  347082  B96 B98        S
# freq                   1   577       7        4      644

# %% [markdown]
# **Here is the what we found so far.**
# **Info**
# >
# > 1. Dimension
#        train_data: 891*12
#        test_data : 418*11
# > 2. Data types
#        Categorical: Survived, Sex, Embarked
#        Ordinal: Pclass
#        Numerical:
#            Continuous: Age, Fare
#            Discrete: PassengerId, SibSp, Parch
#        Mixed: Ticket, Cabin
# > 3. Number of missing values
#        train: Cabin > Age > Embarked
#        test: Cabin > Age > Fare
#
# **Observations**
# >
# >    1. Age-[<1, 80], Fare-[0, 512]
# >    2. Male = 577/891 = 65%, female = 35%
# >    3. Three Embarkation ports
# >    4. Duplication rate of Ticket = 23.6%
#         Duplication rate of Cabin = 27.9%
# >    5. 50% - 75% of passengers travel alone (SibSp, Parch)
#
# **Assumptions**
# >
# >    1. Cabin may be dropped out (Majority of values missed)
# >    2. Ticket may be dropped out (High duplicaiton rate)
# >    3. PassengerId and Name may be dropped out.
# >    4. Combine SibSp and Parch if possible.
# >    5. Age, Embarked, Fare do fillna()
# >    6. From the project description, Sex, Age and Pclass may directly relate to the survival rate

# %% [markdown]
# ## Features Analysis

# %% [markdown]
# ### Pclass vs. Survived

# %%
train_data[['Pclass', 'Survived']].groupby('Pclass').mean().sort_values(by = 'Survived', ascending = False)
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %% [markdown]
# Passengers in 1st class have a higher survival rate of 62.96% on average. Given the tickets in the 1st class are most expensive, that may indicate those who paid more for the ticket are more likely to survive. Let us take a look at fare vs. survived.

# %% [markdown]
# ### Fare vs. Survived

# %%
g = sns.FacetGrid(train_data, col = 'Survived')
g = g.map(sns.distplot, 'Fare', bins = 50, kde = False)
g.set_axis_labels('Fare','Value $')
g.fig.subplots_adjust(top = 0.8)
g.fig.suptitle("Fare vs. Survived")
plt.show()
# Out:
# C:\Users\BRI\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The distribution of fare is skewed. We may want to do **log transfrom** later.
#
# It is clear that the majority of casualties are those who paid less than \\$50 for the tickets. On the flip side, most of passengers paying more than $100 survived. This strengthens our assumption previously. Thus we may want to keep "Pclass" and "Fare" in the model.
#
# We could see that a small amount of passenger who paid less did survive. For the time being, I guess this may be contributed by the gender or age.

# %% [markdown]
# ### Sex vs. Survived

# %%
train_data[['Sex', 'Survived']].groupby('Sex').mean().sort_values('Survived', ascending = False)
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %% [markdown]
# Unsurprisingly the female has a much higher survival rate than the male. We may want to keep "Sex" in the model.

# %% [markdown]
# ### Age vs. Survived

# %%
ticks = [i for i in np.arange(0, 90, 10)]
g = sns.FacetGrid(train_data, col = 'Survived')
g = g.map(sns.distplot, 'Age', bins = 50)
g.set(xticks = ticks)
g.set_axis_labels('Age','Probability')
g.fig.subplots_adjust(top = 0.8)
g.fig.suptitle("Age vs. Survived")
plt.show()
# Out:
# C:\Users\BRI\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\BRI\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Passengers aged < 10 mostly survived, 20-40 mostly not survived, aged 80 survived. We may want to keep "Age" in the model.

# %% [markdown]
# ### SibSp vs. Survived

# %%
sns.barplot(x = train_data['SibSp'], y = train_data['Survived'])
plt.show()

# %% [markdown]
# ### Parch vs. Survived

# %%
sns.barplot(x = train_data['Parch'], y = train_data['Survived'])
plt.show()

# %% [markdown]
# Based on the two graphs above, passengers with SibSp = 1 or 2 and Parch <=3 are more likely to survive. However, the relationship does not seem very strong. It is noticeable that passengers who travelled alone (SibSp = 0 and Parch = 0) have much less chance of survival. Given 50% - 75% of passengers travel alone from section 3.1, we may want to keep 'SibSp'and 'Parch' because we need to indicate the solo travellers.

# %% [markdown]
# ### Embarked vs. Survived

# %%
train_data[['Embarked', 'Survived']].groupby('Embarked').mean().sort_values(by = 'Survived', ascending = False)
# Out:
#           Survived
# Embarked
# C         0.553571
# Q         0.389610
# S         0.336957

# %% [markdown]
# Passengers who embarked on Cherbourg have a higher survival rate. We may need to encode this variable later.

# %% [markdown]
# ### Sex, Pclass, Embarked vs. Survived

# %%
g = sns.FacetGrid(train_data, col = 'Embarked')
g.map(sns.pointplot,'Pclass' ,'Survived', 'Sex', palette = 'bright')
g.fig.subplots_adjust(top = 0.8)
g.fig.suptitle("Sex, Pclass, Embarked vs. Survived")
g.add_legend()
plt.show()
# Out:
# C:\Users\BRI\anaconda3\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# C:\Users\BRI\anaconda3\lib\site-packages\seaborn\axisgrid.py:648: UserWarning: Using the pointplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# Pretty much like what we found , males have a lower average survival rate at Embark S and Q. However, that did not happen at Embark C, raising the question whether the variable 'embarked' would play a role in the model. Also, given there are 644 passengers embarkding on S, we may want to keep 'Embarked' in the model.

# %% [markdown]
# ### Age, Pclass vs. Survived

# %%
g = sns.FacetGrid(train_data, row = 'Pclass', col = 'Survived')
g.map(plt.hist, 'Age')
g.fig.subplots_adjust(top = 0.9)
g.fig.suptitle("Age, Pclass vs. Survived")
plt.show()

# %% [markdown]
# A large number of passengers aged between 20 - 40 did not survive across all classes, while most of kids and seniors survived. Also, the 3rd class has the highest casualities. This is consistent with what we found in the section "Pclass vs. Survived" and "Age vs. Survived".

# %% [markdown]
# ### Heatmap

# %%
sns.heatmap(train_data[['Survived', 'Age', 'SibSp', 'Parch', 'Fare']].corr(), annot=True, cmap='RdYlGn')
plt.show()

# %% [markdown]
# Here the highest correlation exits between SibSp and Parch. Instead of keeping both of them in the model, we will thin them out in order to reduce the noise. Says we may want to create a new variable 'IsAlone' to indicate if a passenger travels alone.

# %% [markdown]
# ### Name

# %% [markdown]
# We are trying to extract the title for each passenger.

# %%
title = [i.split(",")[1].split(".")[0].strip() for i in train_data["Name"]]
title = Counter(title)
title
# Out:
# Counter({'Mr': 517,
#          'Mrs': 125,
#          'Miss': 182,
#          'Master': 40,
#          'Don': 1,
#          'Rev': 6,
#          'Dr': 7,
#          'Mme': 1,
#          'Ms': 1,
#          'Major': 2,
#          'Lady': 1,
#          'Sir': 1,
#          'Mlle': 2,
#          'Col': 2,
#          'Capt': 1,
#          'the Countess': 1,
#          'Jonkheer': 1})

# %% [markdown]
# Titles would be categorized by:
# * Mr/Master: 0
# * Mrs/Miss: 1
# * Others: 2

# %% [markdown]
# **Here is what we are going to do for the feature engineering.**
#
# 1. Drop out PassengerId, Name, Ticket and Cabin.
# 2. Create a new feature 'IsAlone'( = SibSp + Parch + 1) to indicate if a passenger is alone.
# 3. Extract titles from Name.
# 4. Missing value imputation and normalization for numerical features.
# 5. Encode the categorical features.

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# **All feature transformers are encapsulated in custom_estimators.py.**

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Creating the pipeline

# %%
# 'Embarked' has only two missing values
train_data['Embarked'].fillna(value = train_data['Embarked'].value_counts().index[0], inplace=True)
X = train_data.drop('Survived', axis = 1)
y = train_data['Survived']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
num_columns = ['Age', 'Fare']
cat_columns = ['Pclass', 'Sex', 'Embarked', 'IsAlone', 'Title'] # We will create the features 'IsAlone' and 'Title'

# %%
num_pipe = Pipeline([('num_selector', FeatureSelector(num_columns)),
                     ('imputer', SimpleImputer(strategy = 'median')),
                     ('Normalization', StandardScaler())])

# %%
cat_pipe = Pipeline([('cat_selector', FeatureSelector(cat_columns)),
                     ('ohe', OneHotEncoder(sparse = False))])

# %%
union = FeatureUnion([('num', num_pipe),
                      ('cat', cat_pipe)])

# %% [markdown]
# ## Plotting the learning curve

# %% [markdown]
# Here we select a couple of classifiers to see the learning curves.

# %%
learning_curve_pipe = Pipeline([('IsAlone', IsAlone("SibSp", "Parch", 'IsAlone')),
                                ('Title', ExtractName('Title')),
                                ('union', union)])

# %%
X_curve = learning_curve_pipe.fit_transform(X)

# %%
def plot_learning_curve(clf, title, X, y):
    '''
    Plot the test and training learning curve.
    
    Parameters:
        clf: estimator
        title: graph title
    Returns:
        Learning curve
    '''
    
    train_sizes,train_scores,test_scores = learning_curve(clf,X,y,random_state = 42,cv = 5, shuffle = True)

    plt.figure()
    plt.title(title)
    
    ylim = (0.7, 1.01)
    if ylim is not None:
        plt.ylim(*ylim)
        
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                train_scores_mean + train_scores_std, alpha=0.1,
                color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
        label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
        label="Cross-validation score")

    plt.legend(loc="best")
    plt.show()

# %%
plot_learning_curve(LogisticRegression(solver = 'lbfgs'),'Learning Curve of Logistic Regression', X_curve, y)
plot_learning_curve(RandomForestClassifier(n_estimators = 100),'Learning Curve of Random Forest', X_curve, y)
plot_learning_curve(DecisionTreeClassifier(),'Learning Curve of Decision Tree', X_curve, y)
plot_learning_curve(xgb.XGBClassifier(),'Learning Curve of XGBoost', X_curve, y)
plot_learning_curve(SVC(gamma = 'scale'),'Learning Curve of SVM', X_curve, y)
# Out:
# C:\Users\BRI\anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Users\BRI\anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# ...

# %% [markdown]
# * Logistic Regression and SVM: training score decreases and plateaus, and CV score is stagniating - it might be underfitting.
# * Random Forest and Decision Tree: training score is around the maximum along the way, but the gap is huge - it might be overfitting.
# * XGBoost: the gap is relatively small - The best model so far.

# %% [markdown]
# ## Tuning the Hyperparameters

# %% [markdown]
# Here we  tune hyperparameters for XGBoost.

# %%
clf = xgb.XGBClassifier()

pipe = Pipeline([('IsAlone', IsAlone("SibSp", "Parch", 'IsAlone')),
                 ('Title', ExtractName('Title')),
                 ('union', union),
                 ('classifier', clf)])

# %%
param_grid = {'classifier__learning_rate': [0.05, 0.10, 0.15, 0.20, 0.25, 0.30], 
              'classifier__max_depth': [3, 4, 5, 6, 8, 10, 12, 15], 
              'classifier__min_child_weight': [1, 3, 5, 7], 
              'classifier__gamma': [0.0, 0.1, 0.2, 0.3, 0.4], 
              'classifier__colsample_bytree': [0.3, 0.4, 0.5, 0.7],
              'union__num__imputer__strategy': ['median', 'mean']}

grid_search = GridSearchCV(pipe, param_grid, cv = 5, scoring = 'accuracy', n_jobs = -1, verbose = 1)
grid_search.fit(X_train, y_train)
best_model = grid_search.best_estimator_

# training score and CV score
result = "{} is {}"
print(result.format("Training score", grid_search.score(X_train, y_train)))
print(result.format("CV score", grid_search.best_score_))
print(result.format("Best parameter", grid_search.best_params_))

# Accuracy, AUC and F1
y_prediction = best_model.predict(X_test)
pred_proba = best_model.predict_proba(X_test)[:, 1]

print("=" * 100)
print(result.format("Accuracy", accuracy_score(y_test, y_prediction)))
print(result.format("AUC", roc_auc_score(y_test, pred_proba)))
print(result.format("F1 score", f1_score(y_test, y_prediction)))

# Feature importance
feature_importance = best_model.steps[3][1].feature_importances_
num_cols = best_model.named_steps['union'].transformer_list[0][1].steps[0][1].columns.copy()
cat_cols = best_model.named_steps['union'].transformer_list[1][1].steps[1][1].get_feature_names().copy()
num_cols.extend(cat_cols)
df = pd.DataFrame({'Feature': num_cols, 'Feature Importance': feature_importance}).sort_values("Feature Importance", ascending = False)
df
# Out:
# Fitting 5 folds for each of 7680 candidates, totalling 38400 fits

# %% [markdown]
# XGBoost model is time consuming, but the result is impressive where accuracy is 0.85 and AUC is 0.9. By looking at the feature importance table, we could observe that "Sex", "Title"(x4) and 'Pclass"(x0) are the main determinants of survival. I think this is consistent with what is found in the section "Exploratory Data Analysis".

# %% [markdown]
# # Submission

# %%
# Prep the submission
y_pred = pd.Series(best_model.predict(test_data), name = 'Survived')
predict = pd.DataFrame({'PassengerId': test_data['PassengerId'],
                       "Survived": y_pred})

# %%
predict
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# 5            897         0
# 6            898         1
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         0
# 19           911         0
# 20           912         0
# 21           913         0
# 22           914         1
# 23           915         0
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         1
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# ...

# %% [markdown]
# # Model Deployment

# %% [markdown]
# Here are what we are going to do next:
#
# * Build a web app using the final model and Flask
# * Deploy the app to Heroku (Cloud platform)
# * Users visit the web app and get the probability of surval by typing out parameters as instructed (Instructions included in README)

# %% [markdown]
# # Pickle

# %%
pickle.dump(random_forest, open('model_classifier.pkl','wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c9f6c65beb33> in <module>
# ----> 1 pickle.dump(random_forest, open('model_classifier.pkl','wb'))
#
# NameError: name 'random_forest' is not defined
